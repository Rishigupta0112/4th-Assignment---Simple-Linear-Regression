# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:/Users/Rishi/Downloads/Salary_Data (1).csv")

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [YearsExperience, Salary]
# Index: []

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b281b3d490>,
#   <matplotlib.lines.Line2D at 0x1b281b3d760>,
#   <matplotlib.lines.Line2D at 0x1b2821f08b0>,
#   <matplotlib.lines.Line2D at 0x1b2821f0b80>],
#  'caps': [<matplotlib.lines.Line2D at 0x1b281b3da30>,
#   <matplotlib.lines.Line2D at 0x1b281b3dd00>,
#   <matplotlib.lines.Line2D at 0x1b2821f0e50>,
#   <matplotlib.lines.Line2D at 0x1b2821fc160>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1b281b3d1c0>,
#   <matplotlib.lines.Line2D at 0x1b2821f05e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b281b3dfd0>,
#   <matplotlib.lines.Line2D at 0x1b2821fc430>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b2821f02e0>,
#   <matplotlib.lines.Line2D at 0x1b2821fc700>],
#  'means': []}

# %%
data.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df1=scaler.fit_transform(data)
scaled_df=pd.DataFrame(df1,columns=data.columns)
scaled_df.head()
# Out:
#    YearsExperience    Salary
# 0         0.000000  0.019041
# 1         0.021277  0.100094
# 2         0.042553  0.000000
# 3         0.095745  0.068438
# 4         0.117021  0.025514

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df2 = scaler.fit_transform(data)
scaled_df = pd.DataFrame(df2, columns = data.columns)
scaled_df.head()
# Out:
#    YearsExperience    Salary
# 0        -1.510053 -1.360113
# 1        -1.438373 -1.105527
# 2        -1.366693 -1.419919
# 3        -1.187494 -1.204957
# 4        -1.115814 -1.339781

# %%
data=data.rename({'YearsExperience':'years_experience', 'Salary':'salary'},axis=1)
data
# Out:
#     years_experience    salary
# 0                1.1   39343.0
# 1                1.3   46205.0
# 2                1.5   37731.0
# 3                2.0   43525.0
# 4                2.2   39891.0
# 5                2.9   56642.0
# 6                3.0   60150.0
# 7                3.2   54445.0
# 8                3.2   64445.0
# 9                3.7   57189.0
# 10               3.9   63218.0
# 11               4.0   55794.0
# 12               4.0   56957.0
# 13               4.1   57081.0
# 14               4.5   61111.0
# 15               4.9   67938.0
# 16               5.1   66029.0
# 17               5.3   83088.0
# 18               5.9   81363.0
# 19               6.0   93940.0
# 20               6.8   91738.0
# 21               7.1   98273.0
# 22               7.9  101302.0
# 23               8.2  113812.0
# 24               8.7  109431.0
# 25               9.0  105582.0
# 26               9.5  116969.0
# 27               9.6  112635.0
# 28              10.3  122391.0
# 29              10.5  121872.0

# %%
import statsmodels.formula.api as smf
model = smf.ols(formula ='salary~years_experience', data = data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 salary   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Mon, 29 May 2023   Prob (F-statistic):           1.14e-20
# Time:                        11:26:26   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept         2.579e+04   2273.053     11.347      0.000    2.11e+04    3.04e+04
# years_experience  9449.9623    378.755     24.950      0.000    8674.119    1.02e+04
# ==============================================================================
# Omnibus:                        2.140   Durbin-Watson:                   1.648
# Prob(Omnibus):                  0.343   Jarque-Bera (JB):                1.569
# Skew:                           0.363   Prob(JB):                        0.456
# Kurtosis:                       2.147   Cond. No.                         13.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q')
plt.title("Nomral Q-Q plot of residuals")
plt.show()

# %%
np.where(model.resid>10)
# Out:
# (array([], dtype=int64),)

# %%
def get_standardize_values( vals): 
  return (vals - vals.mean())/vals.std()
plt.scatter(get_standardize_values(model.fittedvalues), get_standardize_values(model.resid))
plt.ylabel('Standardize Residual values')
plt.xlabel('Standardize Fitted values')
plt.title('Residual Plot')
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "years_experience", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance
fig = plt.subplots(figsize=(20,8))
plt.stem(np.arange(len(data)), np.round(c,3))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
(np.argmax(c), np.max(c))
# Out:
# (23, 0.13175452313135258)

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %%
k = data.shape[1]
n = data.shape[0]
leverage_cutoff = 3*(k+1)/n
leverage_cutoff
# Out:
# 0.3

# %%
final_ml_v=smf.ols(formula ='salary~years_experience', data = data).fit()
(final_ml_v.rsquared,final_ml_v.aic)
# Out:
# (0.9569566641435086, 606.882316930432)

# %%
newdata = pd.Series([5,10])

# %%
data_pred = pd.DataFrame(newdata, columns = ['years_experience'])
data_pred
# Out:
#    years_experience
# 0                 5
# 1                10

# %%
model.predict(data_pred)
# Out:
# 0     73042.011806
# 1    120291.823413
# dtype: float64
